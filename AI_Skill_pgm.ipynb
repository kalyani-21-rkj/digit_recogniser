# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani-21-rkj/digit_recogniser/blob/main/AI_Skill_pgm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sum of two variable is:
a = 2
b = 3
sum = a + b
sum
# Out:
# 5

# %%
id(a)
# Out:
# 11654408

# %% [markdown]
# Naming Variable

# %% [markdown]
# **1**.variable name should be start from cunderscore and capital.
#
# **2**.variable name never start with  number and special character.
#
# **3**.but we can use numbers or digit in between and at the end of variable
# we cant use special charater anywhere.
#
# **4**.variable in python are case sencitive

# %%
name="kalyani"
print(name)
print(type(name))
# Out:
# kalyani
# <class 'str'>

# %%
#float
a=2.2
print(type(a))
# Out:
# <class 'float'>

# %%
#bool
result=True
print(result)
print(type(result))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# **List**
#
# 1.list is an ordered collection of hectrogenous data type values.
#
# 2.it allow indexing and slicing.
#
# 3.it is mutable in nature.mutability means they can modify the element,add new element and drop exising element.
#
# 4.list allow duplicate element.
#
# 5.list elements enclosed in [] seprated by comma.

# %%
lst=[12,"kalyani",14.35,True,"apple"]
lst
# Out:
# [12, 'kalyani', 14.35, True, 'apple']

# %%
lst[1]
# Out:
# 'kalyani'

# %%
lst[3]
# Out:
# True

# %%
lst[-3]
# Out:
# 14.35

# %% [markdown]
# In python we have **two types of indexing**
#
# 1.**positive indexing**-: it start from 0 and go upto n-1. ii]it travels from left to right.
#
# 2.**Negative indexing** -: it start from -1 and goes upto -n . ii] it travels from right to left

# %%
lst[::-1]
# Out:
# ['apple', True, 14.35, 'kalyani', 12]

# %%
lst=[1,"omkar",34.657,True,89,99,54,21,44,10]
#[21,89,"omakr"]
result=[lst[7],lst[4],lst[1]]
print(result)
# Out:
# [21, 89, 'omkar']

# %%
lst[-3:0:-3]
# Out:
# [21, 89, 'omkar']

# %%
#modify element
lst=[1,"omkar",34.657,True,89,99,54,21,44,10]
lst[1]="kalyani"
lst
# Out:
# [1, 'kalyani', 34.657, True, 89, 99, 54, 21, 44, 10]

# %%
lst=[1,2,3]
lst.append(4)
lst
# Out:
# [1, 2, 3, 4]

# %%
lst.extend([5,6,7])
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# **Insert function**

# %%
lst=[2,3,4]
lst.insert(1,11)
lst
# Out:
# [2, 11, 3, 4]

# %%
lst.pop(0)
lst
# Out:
# [3, 4]

# %%
#clear function remove all the elements
lst=[2,3,4]
lst.clear()
lst
# Out:
# []

# %% [markdown]
# **Tuple**
#
# 1.tuple is an ordered collection of hetrogeneous datatype.
#
# 2.it follow indexing and slicing.
#
# 3.it is immutable in nature.which means we cant modify the the element,add the element and delete existiing element.
#
# 4.tuple allow duplicate values.
#
# 5.tuple enclose in ( ) and seprated by comma.
